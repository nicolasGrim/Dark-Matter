# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
nu_e = pd.read_csv('data/effArea/nu_e.csv', delimiter = ';', names = ['E', 'Aeff'], decimal = ',')
nu_mu = pd.read_csv('data/effArea/nu_mu.csv',  delimiter = ';', decimal = ',')
nu_tau = pd.read_csv('data/effArea/nu_tau.csv',  delimiter = ';', names = ['E', 'Aeff'], decimal = ',')

# %%
nu_e
# Out:
#               E      Aeff
# 0     11.294970  0.000005
# 1     11.797971  0.000006
# 2     12.323469  0.000006
# 3     12.872228  0.000007
# 4     13.445539  0.000008
# ..          ...       ...
# 97   771.693649  0.002341
# 98   806.029883  0.002421
# 99   841.888910  0.002476
# 100  879.337008  0.002498
# 101  904.030993  0.002517
#
# [102 rows x 2 columns]

# %%
nu_mu
# Out:
#               E      Aeff
# 0     11.477496  0.000006
# 1     11.987417  0.000007
# 2     12.519993  0.000008
# 3     13.076230  0.000009
# 4     13.657180  0.000010
# ..          ...       ...
# 96   745.041477  0.001796
# 97   778.142119  0.001867
# 98   812.713352  0.001941
# 99   848.820514  0.002018
# 100  886.531841  0.002083
#
# [101 rows x 2 columns]

# %%
nu_tau
# Out:
#               E          Aeff
# 0     11.477496  7.968707e-07
# 1     11.987417  9.149023e-07
# 2     12.519993  1.077379e-06
# 3     13.076230  1.257245e-06
# 4     13.657180  1.482236e-06
# ..          ...           ...
# 96   745.041477  2.343010e-03
# 97   778.142119  2.436683e-03
# 98   812.713352  2.538701e-03
# 99   848.820514  2.617424e-03
# 100  883.035399  2.702780e-03
#
# [101 rows x 2 columns]

# %%
fig, ax = plt.subplots(1, 1, dpi = 300, figsize = (16, 9))

nu_e.plot(kind = 'scatter', x = 'E', y = 'Aeff', ax = ax, loglog = True, color = 'r', label = '$\\nu_e$')
nu_mu.plot(kind = 'scatter', x = 'E', y = 'Aeff', ax = ax, loglog = True, color = 'g', label = '$\\nu_\\mu$')
nu_tau.plot(kind = 'scatter', x = 'E', y = 'Aeff', ax = ax, loglog = True, color = 'b', label = '$\\nu_\\tau$')

ax.set_ylabel('Effective area [$m^2$]')
ax.set_xlabel('$E_{MC}$ [GeV]')

ax.legend()
ax.grid()

ax.set_xlim(10, 1000)
ax.set
# Out:
# Text(0.5, 0, '$E_{MC}$ [GeV]')
